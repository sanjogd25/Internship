# %%
#a python program to scrape house details from nobroker

# %%
# !pip install bs4
# !pip install requests
# Out:
# Requirement already satisfied: bs4 in c:\users\dhanv\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\dhanv\anaconda3\lib\site-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\dhanv\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.2.1)
# Requirement already satisfied: requests in c:\users\dhanv\anaconda3\lib\site-packages (2.25.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dhanv\anaconda3\lib\site-packages (from requests) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\dhanv\anaconda3\lib\site-packages (from requests) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dhanv\anaconda3\lib\site-packages (from requests) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\dhanv\anaconda3\lib\site-packages (from requests) (2.10)

# %%
from bs4 import BeautifulSoup
import requests 
import pandas as pd

# %%
page = requests.get('https://www.nobroker.in/property/sale/mumbai/multiple?searchParam=...&radius=2.0&city=mumbai&locality=Indira%20Nagar,&locality=Jaya%20Nagar,&locality=Rajajinagar')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta content="794951570520699" property="fb:pages"/>
# <link href="https://www.nobroker.in" rel="canonical"/>
# <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
# <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# <link href="//assets.nobroker.in" rel="dns-prefetch"/>
# <link href="//images.nobroker.in" rel="dns-prefetch"/>
# <link href="https://assets.adobedtm.com" rel="dns-prefetch"/>
# <link href="//assets.nobroker.in/static/img/favicon.png" id="favicon" rel="shortcut icon"/>
# <link href="https://images.nobroker.in/static/img/fav64.png" rel="apple-touch-icon"/>
# <!--<meta charset="utf-8"/>-->
# <meta charset="utf-8"/>
# <meta content="app-id=com.nobroker.app&amp;referrer=utm_source%3Dnobroker%26utm_medium%3DmobileWeb" name="google-play-app"/>
# <meta content="app-id=1200507100, app-argument=nobrokerapp://" name="apple-itunes-app"/>
# <meta content="#fd3752" name="theme-color"/>
# <meta content="flats for sale in Indira Nagar,,   apartments for sale in Indira Nagar,,  houses for sale in Indira Nagar," name="keywords"/>
# <meta content="Flats, Apartments for Sale in Indira Nagar,, Mumbai |  Flats in Indira Nagar,  - NoBroker" property="og:title"/>
# <meta content="Searching   Flats, Apartments for SALE in Indira Nagar,, Mumbai ? Get verified list of flats for sale WITHOUT BROKER and SAVE YOUR MONEY" property="og:description"/>
# <meta content="https://www.nobroker.in" property="og:url"/>
# <meta content="https://assets.nobroker.in/nb-new/public/List-Page/ogImage.png" property="og:image"/>
# <meta content="@nobrokercom" name="twitter:site"/>
# <meta content="Flats, Apartments for Sale in Indira Nagar,, Mumbai |  Flats in Indira Nagar,  - NoBroker" name="twitter:title"/>
# <meta content="Searching   Flats, Apartments for SALE in Indira Nagar,, Mumbai ? Get verified list of flats for sale WITHOUT BROKER and SAVE YOUR MONEY" name="twitter:description"/>
# <meta content="https://assets.nobroker.in/nb-new/public/List-Page/ogImage.png" name="twitter:image"/>
# <meta content="360" property="og:image:height"/>
# <meta content="540" property="og:image:width"/>
# <meta content="289265624583131" property="fb:app_id"/>
# <meta content="NoBroker" property="og:site_name"/>
# <meta content="product" property="og:type"/>
# <meta content="notranslate" name="google"/>
# <meta content="hLy7ta67b2CS6LQFWI3SrB22XIuKUHlAHGEi-0W0ngI" name="google-site-verification"/>
# <meta content="81EEED055BF8993A564A4B24AF189813" name="msvalidate.01"/>
# <meta content="e5c74d79345e920627558faecd28fae5" name="p:domain_verify"/>
# <meta content="239876242888-mbq11kse03n78gs2o5549clvlcv3ls24.apps.googleusercontent.com" name="google-signin-client_id"/>
# <meta content="index, follow" name="robots"/>
# <title>Flats, Apartments for Sale in Indira Nagar,, Mumbai |  Flats in Indira Nagar,  - NoBroker</title>
# <meta content="Searching   Flats, Apartments for SALE in Indira Nagar,, Mumbai ? Get verified list of flats for sale WITHOUT BROKER and SAVE YOUR MONEY" name="description"/>
# <meta content="width=device-width,initial-scale=1,shrink-to-fit=no,maximum-scale=1.0" name="viewport"/>
# <meta content="IE=edge,chrome=1" name="X-UA-Compatible"/>
# <link href="https://assets.nobroker.in/static/img/favicon.png" rel="icon"/>
# <link href="/manifest.json" rel="manifest"/>
# <link as="font" crossorigin="" href="https://fonts.gstatic.com/s/sourcesanspro/v13/6xKydSBYKcSV-LCoeQqfX1RYOo3ik4zwlxdu.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://fonts.gstatic.com/s/sourcesanspro/v13/6xK3dSBYKcSV-LCoeQqfX1RYOo3qOK7l.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://fonts.gstatic.com/s/sourcesanspro/v13/6xKydSBYKcSV-LCoeQqfX1RYOo3i54rwlxdu.woff2" rel="preload" type="font/woff2"/>
# <style>
#             @font-face {
#               font-family: 'Source Sans Pro';
#               font-style: normal;
#               font-weight: 300;
#               font-display: swap;
#               src: local('Source Sans Pro Light'), local('SourceSansPro-Light'), url(https://fonts.gstatic.com/s/sourcesanspro/v13/6xKydSBYKcSV-LCoeQqfX1RYOo3ik4zwlxdu.woff2) format('woff2');
#               unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
#             }
#             @font-face {
#               font-family: 'Source Sans Pro';
#               font-style: normal;
#               font-weight: 400;
#               font-display: swap;
#               src: local('Source Sans Pro Regular'), local('SourceSansPro-Regular'), url(https://fonts.gstatic.com/s/sourcesanspro/v13/6xK3dSBYKcSV-LCoeQqfX1RYOo3qOK7l.woff2) format('woff2');
#               unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
#             }
#             @font-face {
#               font-family: 'Source Sans Pro';
#               font-style: normal;
#               font-weight: 600;
#               font-display: swap;
#               src: local('Source Sans Pro SemiBold'), local('SourceSansPro-SemiBold'), url(https://fonts.gstatic.com/s/sourcesanspro/v13/6xKydSBYKcSV-LCoeQqfX1RYOo3i54rwlxdu.woff2) format('woff2');
#               unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
#             }
#           </style>
# <script>
#               window.dataLayer = [];
#             </script>
# <!-- Google Tag Manager -->
# <script>
#                       var interval = setInterval(function() {
#                         if (document && document.readyState === 'complete') {
#                           clearInterval(interval);
#                           (function(w, d, s, l, i) {
#                             w[l] = w[l] || [];
#                             w[l].push({ 'gtm.start': new Date().getTime(), event: 'gtm.js' });
#                             var f = d.getElementsByTagName(s)[0],
#                               j = d.createElement(s),
#                               dl = l != 'dataLayer' ? '&l=' + l : '';
#                             j.async = true;
#                             j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#                             f.parentNode.insertBefore(j, f);
#                           })(window, document, 'script', 'dataLayer', 'GTM-NDNFVM5');
#                         }
#                       }, 100);
#                     </script>
# <!-- End Google Tag Manager -->
# <link href="https://assets.nobroker.in/nb-new/public/css/slick.min.css" rel="stylesheet" type="text/css"/>
# <link href="https://assets.nobroker.in/nb-new/public/css/slick-theme.min.css" rel="stylesheet" type="text/css"/>
# <script>
#             window.googleMapLoadCallBack = function() {};
#           </script>
# <script async="" defer="" src="https://maps.googleapis.com/maps/api/js?key=AIzaSyDUznTiPcMB6dsRkOq9ZLNrKLCzVZzvZXo&amp;v=3.exp&amp;libraries=places,geometry&amp;callback=googleMapLoadCallBack" type="text/javascript"></script>
# <link data-chunk="PropertyDropdown" href="https://assets.nobroker.in/nb-new/PropertyDropdown/PropertyDropdown.fde01df5a8cb1c2ea81a.css" rel="stylesheet"/>
# <link data-chunk="HeaderContentDesktop" href="https://assets.nobroker.in/nb-new/HeaderContentDesktop/HeaderContentDesktop.b512f9fe5be03f036245.css" rel="stylesheet"/>
# <link data-chunk="NbButton" href="https://assets.nobroker.in/nb-new/NbButton/NbButton.5a06d9b3e427a79f3d2b.css" rel="stylesheet"/>
# <link data-chunk="NbTooltip" href="https://assets.nobroker.in/nb-new/NbTooltip/NbTooltip.cecedd1fc7117fd4367e.css" rel="stylesheet"/>
# <link data-chunk="ListPageSearchHeaders" href="https://assets.nobroker.in/nb-new/ListPageSearchHeaders/ListPageSearchHeaders.9d77117bbacada15afad.css" rel="stylesheet"/>
# <link data-chunk="ListPageListViews" href="https://assets.nobroker.in/nb-new/ListPageListViews/ListPageListViews.195849793271bff9a9b9.css" rel="stylesheet"/>
# <link data-chunk="ListPageFilterss" href="https://assets.nobroker.in/nb-new/ListPageFilterss/ListPageFilterss.26b9a33c150dd46ec7a2.css" rel="stylesheet"/>
# <link data-chunk="SaleFilterss" href="https://assets.nobroker.in/nb-new/SaleFilterss/SaleFilterss.ca4de1984b5c92bd790b.css" rel="stylesheet"/>
# <link data-chunk="ListPageBreadcrumbs" href="https://assets.nobroker.in/nb-new/ListPageBreadcrumbs~listPageBreadCrumb/ListPageBreadcrumbs~listPageBreadCrumb.875ca23345442497a26e.css" rel="stylesheet"/>
# <link data-chunk="ListPageBreadcrumbs" href="https://assets.nobroker.in/nb-new/ListPageBreadcrumbs/ListPageBreadcrumbs.dddc016636f6bd26682b.css" rel="stylesheet"/>
# <link data-chunk="VerticalListPageAdCards" href="https://assets.nobroker.in/nb-new/VerticalListPageAdCards/VerticalListPageAdCards.5f6c0a90a790b23ae4e1.css" rel="stylesheet"/>
# <link data-chunk="main" href="https://assets.nobroker.in/nb-new/css/main.bc7e117031c63c8f74d8.css" rel="stylesheet"/>
# <script async="" src="https://assets.nobroker.in/nb-new/public/js/instantgratification.001.js"></script>
# <script>
#             window.nb = window.nb || {};
#             nb.pageName = "listPage";
#             nb.appState = {"route":{"location":null},"global":{"requestData":null},"signupReducer":{"phoneExistLoading":false,"phoneStatus":null,"otpVerification":null,"emailOtpVerification":null,"passwordVerification":null,"newAccountData":null,"newUser":false,"oldUser":false,"userInfo":null,"newAccountDataError":"","userPhoneData":{},"adobeSignupEventCalled":false},"commonReducer":{"status":"","userInfo":null,"fetchedUserInfo":false,"walletBalance":0,"signupModal":{},"showAlertMsg":false,"notFound":false,"crowdLeadAdded":null,"openAlertsModal":false,"planDetailInfos":null,"tenantPlanInfo":null,"pagename":null,"userNotificationCount":null,"photoRequestData":null,"propertyId":null,"fromChat":null,"feedBackData":null,"feedBackUpdatedData":null,"openSchedularModal":false,"openScheduleVisitModal":false,"slotsData":null,"bookedSlotData":null,"userEmailSave":null,"walletEnabled":false,"propertyTrendsData":null,"instantLeadData":null,"instantBookData":null,"tenantLeadData":null,"scheduleVisitTimeData":null,"contactedInfoData":null,"hub":null,"contactedIdsForListPage":[],"contactedNotVerifiedIdsForListPage":[],"visitSlotsData":null,"hoodExploreRefreshToken":null,"isBasicPlanSuccess":false,"selectedSearchFilterData":{},"preselectedLocalitiesData":[],"listingData":null,"shortlistedProperty":null,"isPayFirstAbFlow":null},"googleSignInReducer":{"loading":false,"userSocialDetail":null},"facebookSignInReducer":{"loading":false,"userFacebookDetail":null},"alertsReducer":{"postAlersSuccess":""},"listAlertsReducer":{"postAlersSuccess":"","alertRequirementId":null,"recommendedProperties":null,"loading":false,"searchRequirementLoading":false},"listPage":{"loading":false,"listPageProperties":[{"propertyAge":10,"ownershipType":"FREEHOLD","parking":"BOTH","parkingDesc":"Bike and Car","contactedStatusDetails":{},"shortlistedByLoggedInUser":false,"lastUpdateDate":1636183818000,"balconies":4,"negotiable":true,"type":"BHK2","ownerId":"8a9f930576141b73017614b67c442a64","regCostIncluded":false,"photos":[{"imagesMap":{"thumbnail":"8a9fb5827cf40f7f017cf415d578032a_97783_972834_thumbnail.jpg","original":"8a9fb5827cf40f7f017cf415d578032a_97783_769088_original.jpg","large":"8a9fb5827cf40f7f017cf415d578032a_97783_249293_large.jpg","medium":"8a9fb5827cf40f7f017cf415d578032a_97783_192921_medium.jpg"},"disAffinity":13,"displayPic":true,"w":562,"name":"image","h":750,"state":"APPROVED","duplicate":false,"title":""}],"availableFrom":1638297000000,"loanAvailable":true,"propertySize":1110,"originalImageUrl":"\u002F\u002Fassets.nobroker.in\u002F8a9fb5827cf40f7f017cf415d578032a_97783_769088_original.jpg","score":{"lastUpdatedDate":"2021-11-06T13:12:00+05:30","transit":6.2,"id":"8a9fb5827cf40f7f017cf415d578032a","lifestyle":7.3},"price":18000000,"id":"8a9fb5827cf40f7f017cf415d578032a","state":"READY","localityId":"borivali_east_mumbai","adminEvent":"PROPERTY","bathroom":2,"propertyTitle":"2 BHK Flat  For Sale  In Dimple La Vista In Borivali East","plotArea":0,"longitude":72.872367,"indexName":"nobroker_resale","seoDescription":"[{\"localityId\": \"ChIJE8w_8-6w5zsRhsViojU7j98\", \"name\": \"Movie Time\", \"longitude\": 72.86306579999999, \"seoUrl\": \"\u002Fflats-for-sale-near-movie_time_dahisar_east_mumbai\", \"latitude\": 19.251938600000006, \"id\": \"ChIJo_i29OWw5zsRKQOou3W2A-0\"}, {\"localityId\": \"ChIJyyvQMc6w5zsRedXXF-xXzU0\", \"name\": \"Sona Gold Digital Cinema\", \"longitude\": 72.8649449, \"seoUrl\": \"\u002Fflats-for-sale-near-sona_gold_digital_cinema_borivali_east_mumbai\", \"latitude\": 19.2347888, \"id\": \"ChIJA9sXxM-w5zsRuDoF5Ih6-SQ\"}, {\"localityId\": \"ChIJE8w_8-6w5zsRhsViojU7j98\", \"name\": \"Pangat The Family Restaurant\", \"longitude\": 72.86491459999998, \"seoUrl\": \"\u002Fflats-for-sale-near-pangat_the_family_restaurant_dahisar_east_mumbai\", \"latitude\": 19.2403574, \"id\": \"ChIJq6qqqgOx5zsRgVh6fQS8Fjw\"}, {\"localityId\": \"ChIJyyvQMc6w5zsRedXXF-xXzU0\", \"name\": \"Borivali Train Station\", \"longitude\": 72.8574025, \"seoUrl\": \"\u002Ff ...
#           </script>
# <script src="//assets.adobedtm.com/e0b9255c6246/62e4c383fb62/launch-2f72a0f28dd3.min.js"></script>
# </head>
# <body>
# <div id="appPortal"></div>
# <div id="app"><div class="app-wrapper"><main class="text-defaultcolor" id="listPageTop" style="background-color:#f2f2f2"><header class="fixed top-0 left-0 w-full z-10" id="navheaderContainer"><nav class="p-0.5p h-6.1p bg-white fixed top:0 left-0 w-full z-30 flex justify-between items-center flex-nowrap flex-row tp:h-5p tp:justify-center" id="navHeader" style="box-shadow:none"><div class="hidden tp:flex absolute left-1.5p"><div class="cursor-pointer inline-block w-auto m-auto transition-all duration-500 ease-linear"><div class="block h-0.2p w-2.4p bg-black transition-all duration-500 ease-in-out my-0.5p mx-auto"></div><div class="block h-0.2p bg-black transition-all duration-500 ease-in-out my-0 mx-auto"></div><div class="block h-0.2p w-2.4p bg-black transition-all duration-500 ease-in-out my-0.5p mx-auto"></div></div></div><div class="cursor-pointer flex items-center tp:flex-row"><div class="desktop-logo pl-1.5p po:flex po:items-center po:justify-center po:absolute po:left-5p"><img alt="logo" src="https://assets.nobroker.in/static/img/logos/nb_logo_new_trans.svg" style="width:170px"/> </div><span class="po:hidden tp:hidden align-middle ml-2p inline-block sd-0.5p"></span><span class="po:hidden tp:hidden float-right mt-2p"><div><div class="nb__2tUBf"><div class="nb__2KTvI"><span class="heading-6">Buy</span><svg aria-hidden="true" class="jss1" focusable="false" role="presentation" viewbox="0 0 24 24"><path d="M16.59 8.59L12 13.17 7.41 8.59 6 10l6 6 6-6z"></path><path d="M0 0h24v24H0z" fill="none"></path></svg></div></div></div></span></div><div class="hidden tp:flex tp:items-center tp:absolute tp:right-1.2p"></div><div class="hidden tp:flex"></div><div class="tp:hidden flex nb__34X7q"><div class="nb__3LW6a"><div class="my-booking nb__3PfOV"><div class="nb__19hcF nb__1NeJE" id="myBooking"><div class="nb__-RK2d"><img alt="rent" src="https://assets.nobroker.in/nb-new/public/myBooking.svg"/></div><div class="nb__RETEr">My Bookings</div></div></div><div class="nb__3PfOV"><div class="nb__19hcF nb__28ebc" id="rentPayment"><div class="nb__3BKJW"><img alt="rent" src="https://assets.nobroker.in/nb-new/public/payrent.png"/></div><div>Pay Rent</div></div></div><a class="block tp:hidden nb__3PfOV" href="/list-your-property-for-rent-sale" rel="noopener noreferrer" target="_blank"><div class="nb__19hcF nb__1VU1p"><button class="btn btn-default btn-sm" id="headerHouseOwner" type="button">Post Your Property<span class="tooltip-trigger-text"></span></button></div></a></div><div class="nb__31B79"><div class="nb__3PfOV"><div class="nb__19hcF">Sign up</div></div><div class="nb__3PfOV"><div class="nb__19hcF">Log in</div></div><div class="nb__3PfOV nb__rZaSw" id="main-menu" tabindex="0"><div class="nb__19hcF"><svg aria-hidden="true" class="jss1 nb__32CYe" focusable="false" role="presentation" viewbox="0 0 24 24"><path d="M2 15.5v2h20v-2H2zm0-5v2h20v-2H2zm0-5v2h20v-2H2z"></path><path d="M0 0h24v24H0z" fill="none"></path></svg>Menu</div><div class="nb__3lEcy"><a class="nb__3Tx_U nb__3F1qW">Post Your Property</a><a class="nb__3Tx_U nb__2jlgw">Rental Agreement</a><a class="nb__3Tx_U nb__2jlgw">Painting &amp; Cleaning</a><a class="nb__3Tx_U nb__2jlgw">Refer &amp; Earn</a><a class="nb__3Tx_U nb__2jlgw">Rent Receipts</a><a class="nb__3Tx_U nb__2jlgw">Tenant Plans</a><a class="nb__3Tx_U nb__2jlgw">Owner Plans</a><a class="nb__3Tx_U nb__2jlgw">Buyer Plans</a><a class="nb__3Tx_U nb__2jlgw">Seller Plans</a><div><div class="nb__3Tx_U"><span>Commercial Plans</span><svg class="menu-arrow-icon-down" color="#999" height="13" style="width:13px;height:13px;margin:2px" viewbox="0 0 24 24" width="13"><path class="" d="M16.62,2.99 C16.13,2.5 15.34,2.5 14.85,2.99 L6.54,11.3 C6.15,11.69 6.15,12.32 6.54,12.71 L14.85,21.02 C15.34,21.51 16.13,21.51 16.62,21.02 C17.11,20.53 17.11,19.74 16.62,19.25 L9.38,12 L16.63,4.75 C17.11,4.27 17.11,3.47 16.62,2.99 Z" fill="#999"></path></svg></div></div><a class="nb__3Tx_U nb__2jlgw">Careers</a><a class="nb__3Tx_U nb__2jlgw">Corporate Enquir ...
# <script async="" data-chunk="listPage" src="https://assets.nobroker.in/nb-new/1/1.70f6d691a002a609055e.chunk.js"></script>
# <script async="" data-chunk="listPage" src="https://assets.nobroker.in/nb-new/2/2.04328b398baf4c95a2e0.chunk.js"></script>
# <script async="" data-chunk="listPage" src="https://assets.nobroker.in/nb-new/vendors~bproject~chat~chats~cpms-kyc~creditScore~detailPage~home~home-about-us~home-services~kyr~leg~9b29c3a9/vendors~bproject~chat~chats~cpms-kyc~creditScore~detailPage~home~home-about-us~home-services~kyr~leg~9b29c3a9.5eb7b09c0602278f3374.chunk.js"></script>
# <script async="" data-chunk="listPage" src="https://assets.nobroker.in/nb-new/vendors~careers~chat~detailPage~listPage~new-projects~privacy~rentListPage/vendors~careers~chat~detailPage~listPage~new-projects~privacy~rentListPage.c33bf709e8179f30e13b.chunk.js"></script>
# <script async="" data-chunk="listPage" src="https://assets.nobroker.in/nb-new/listPage/listPage.4f1fe725046074facc0b.chunk.js"></script>
# <script async="" data-chunk="PropertyDropdown" src="https://assets.nobroker.in/nb-new/0/0.4c19445671f7db956367.chunk.js"></script>
# <script async="" data-chunk="PropertyDropdown" src="https://assets.nobroker.in/nb-new/vendors~PropertyDetailHeader~PropertyDropdown/vendors~PropertyDetailHeader~PropertyDropdown.92413915e1a314b146e5.chunk.js"></script>
# <script async="" data-chunk="PropertyDropdown" src="https://assets.nobroker.in/nb-new/PropertyDropdown/PropertyDropdown.e0c8304060d725adf8f4.chunk.js"></script>
# <script async="" data-chunk="HeaderContentDesktop" src="https://assets.nobroker.in/nb-new/HeaderContentDesktop/HeaderContentDesktop.d1e9b34673478cc3881b.chunk.js"></script>
# <script async="" data-chunk="NbButton" src="https://assets.nobroker.in/nb-new/NbButton/NbButton.a2acfcadbe706a31dadd.chunk.js"></script>
# <script async="" data-chunk="NbTooltip" src="https://assets.nobroker.in/nb-new/NbTooltip/NbTooltip.d0b85610a8a9c15279e0.chunk.js"></script>
# <script async="" data-chunk="ListPageSearchHeaders" src="https://assets.nobroker.in/nb-new/4/4.2097d07fff77662091fc.chunk.js"></script>
# <script async="" data-chunk="ListPageSearchHeaders" src="https://assets.nobroker.in/nb-new/vendors~Alert~CommercialFilterss~ListPageAlerts~ListPageSearchHeaders~MapListView~NbSlider~PaymentCa~93047457/vendors~Alert~CommercialFilterss~ListPageAlerts~ListPageSearchHeaders~MapListView~NbSlider~PaymentCa~93047457.1dda39e6af8bf86091b7.chunk.js"></script>
# <script async="" data-chunk="ListPageSearchHeaders" src="https://assets.nobroker.in/nb-new/vendors~ListPageSearchHeader~ListPageSearchHeaders~NbGoogleAutoCompleteMultiSearch/vendors~ListPageSearchHeader~ListPageSearchHeaders~NbGoogleAutoCompleteMultiSearch.e05b04b49e6e31afbb5e.chunk.js"></script>
# <script async="" data-chunk="ListPageSearchHeaders" src="https://assets.nobroker.in/nb-new/ListPageSearchHeaders/ListPageSearchHeaders.b54bcc809d76d590f7ee.chunk.js"></script>
# <script async="" data-chunk="ListPageListViews" src="https://assets.nobroker.in/nb-new/vendors~ListPageListViews~RentListView/vendors~ListPageListViews~RentListView.c742e5c82459e1901f16.chunk.js"></script>
# <script async="" data-chunk="ListPageListViews" src="https://assets.nobroker.in/nb-new/ListPageListViews/ListPageListViews.0e646ca5d6e499dcffc8.chunk.js"></script>
# <script async="" data-chunk="ListPageFilterss" src="https://assets.nobroker.in/nb-new/ListPageFilterss/ListPageFilterss.c77981c040eafeb4c73a.chunk.js"></script>
# <script async="" data-chunk="SaleFilterss" src="https://assets.nobroker.in/nb-new/6/6.3a1e45ee2f0ab6912608.chunk.js"></script>
# <script async="" data-chunk="SaleFilterss" src="https://assets.nobroker.in/nb-new/SaleFilterss/SaleFilterss.f0bd592ca1686e53aa3d.chunk.js"></script>
# <script async="" data-chunk="ListPageBreadcrumbs" src="https://assets.nobroker.in/nb-new/ListPageBreadcrumbs~listPageBreadCrumb/ListPageBreadcrumbs~listPageBreadCrumb.0ba5cd5031124285ba90.chunk.js"></script>
# <script async="" data-chunk="ListPageBreadcrumbs" src="https://assets.nobroker.in/nb-new/ListPageBreadcrumbs/ListPageBreadcrumbs.767eb569a2c4c981b172.chunk.js"></script>
# <script async="" data-chunk="VerticalListPageAdCards" src="https://assets.nobroker.in/nb-new/9/9.62a4a439b1532437c0c5.chunk.js"></script>
# <script async="" data-chunk="VerticalListPageAdCards" src="https://assets.nobroker.in/nb-new/14/14.84a757ec753f464500ea.chunk.js"></script>
# <script async="" data-chunk="VerticalListPageAdCards" src="https://assets.nobroker.in/nb-new/vendors~VerticalListPageAdCards/vendors~VerticalListPageAdCards.c89078e13d8534ed88c4.chunk.js"></script>
# <script async="" data-chunk="VerticalListPageAdCards" src="https://assets.nobroker.in/nb-new/VerticalListPageAdCards/VerticalListPageAdCards.ba90b9825ff09b691737.chunk.js"></script>
# <script async="" data-chunk="main" src="https://assets.nobroker.in/nb-new/vendor/vendor.4778518ecfa2f2a721d6.chunk.js"></script>
# <script async="" data-chunk="main" src="https://assets.nobroker.in/nb-new/main.0743b3c012fa954f5bc6.js"></script>
# <img alt="" height="1" id="adobe-event" src="" style="display: none" width="1"/>
# <noscript>If you're seeing this message, that means <strong>JavaScript has been disabled on your browser</strong>, please <strong>enable JS</strong> to make this app work.</noscript>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NDNFVM5" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <script>digitalData={},window.isGAinit=!1</script>
# </body>
# </html>

# %%
housetitle = []
location = []
area = []
price = []
emi = []
for i in soup.find_all('span',class_="capitalize text-defaultcolor mb-0.5p font-semibold no-underline hover:text-primary-color po:overflow-hidden po:overflow-ellipsis po:max-w-95 po:m-0 po:font-normal group-hover:text-primary-color group-hover:nounderline"):
    housetitle.append(i.text)
for i in soup.find_all('div',class_="mt-0.5p overflow-hidden overflow-ellipsis whitespace-nowrap max-w-70 text-gray-light leading-4 po:mb-0 po:max-w-95"):
    location.append(i.text)
for i in soup.find_all('div',class_="flex flex-col w-33pe items-center border-r border-r-solid border-card-overview-border-color tp:w-half po:w-full last:border-r-1", itemprop="additionalProperty"):
    area.append(i.text)
for i in soup.find_all('div',class_="font-semi-bold heading-6", id="roomType"):
    price.append(i.text)

# %%
data = {'House': housetitle, 'Location': location, 'Area': area, 'Price': price}
print(len(housetitle),len(location), len(price),len(area))
df = pd.DataFrame.from_dict(data, orient='columns')
df = df.transpose()
print(df)
# Out:
# 25 25 25 25
#                                                          0   \
# House     2 BHK Flat  For Sale  In Dimple La Vista In Bo...
# Location  Near Abhinav Nagar, Borivali East, Mumbai, Mah...
# Area                                      1,110 sqftBuiltup
# Price                                      ₹1.03 Lacs/Month
#
#                                                          1   \
# House     1 BHK In Independent House  For Sale  In Dahis...
# Location  Independent House, hanuman tedki near saibaba ...
# Area                                        300 sqftBuiltup
# Price                                         ₹14,328/Month
#
#                                                          2   \
# House     1 RK Flat  For Sale  In Shivkakan Chs In Boriv...
# Location             Hanuman Tekdi Rd, near Sai Baba Mandir
# Area                                        350 sqftBuiltup
# Price                                         ₹31,522/Month
#
#                                                          3   \
# House     1 BHK Flat  For Sale  In Shiv Sai Chs In Boriv...
# Location  B-101, Borivali East, Mumbai, Maharashtra 4000...
# Area                                        455 sqftBuiltup
# Price                                         ₹42,985/Month
#
#                                                          4   \
# House     1 BHK In Independent House  For Sale  In Boriv...
# Location  Independent House, Hanuman Tekdi near Ambe Mat...
# Area                                        450 sqftBuiltup
# Price                                         ₹22,925/Month
#
#                                                          5   \
# House     1 RK In Independent House  For Sale  In Boriva...
# Location  Independent House, Hanuman Tekdi near Ambe Mat...
# Area                                        160 sqftBuiltup
# Price                                         ₹14,328/Month
#
#                                                          6   \
# House     2 BHK Flat  For Sale  In Ashokvan Apartment In...
# Location          Dahisar East, Mumbai, Maharashtra, INDIA.
# Area                                        750 sqftBuiltup
# Price                                         ₹74,508/Month
#
#                                                          7   \
# House     1 BHK Flat  For Sale  In Shiv Vallabh Road, Bo...
# Location                        Ashokvan, Vivek Kambli Marg
# Area                                        550 sqftBuiltup
# Price                                         ₹45,565/Month
#
#                                                          8   \
# House     2 BHK Flat  For Sale  In La-bellezza In Boriva...
# Location  Rishivan, Next to Sant Gadge Maharaj Marg, Kaj...
# Area                                        915 sqftBuiltup
# Price                                         ₹71,643/Month
#
#                                                          9   ...  \
# House     3 BHK Apartment  For Sale  In La-bellezza. In ...  ...
# Location  La-Bellezza.  Rishivan, Next to, Sant Gadge Ma...  ...
# Area                                        915 sqftBuiltup  ...
# Price                                         ₹65,911/Month  ...
#
#                                                          15  \
# House     2 BHK Flat  For Sale  In Aditya Aryan In Borivali
# Location  B-101, Kajupada, Borivali East, Mumbai, Mahara...
# Area                                        720 sqftBuiltup
# Price                                         ₹79,667/Month
#
#                                                          16  \
# House     1 BHK Apartment  For Sale  In Gautam Chs In Bo...
# Location        Gautam Chs  Kajupada, Near Om Siddharaj CHS
# Area                                        510 sqftBuiltup
# Price                                         ₹45,851/Month
#
#                                                          17  \
# House     1 BHK Apartment  For Sale  In Sahara Sahara Ch...
# Location                   Sahara Sahara Chs  Nenci Colony
# Area                                        565 sqftBuiltup
# Price                                         ₹67,057/Month
#
#                                                          18  \
# House     2 BHK Flat  For Sale  In Morya Avenue In Boriv...
# Location                  Chogle Nagar, Behind shani mandir
# Area                                        743 sqftBuiltup
# Price                                         ₹74,508/Month
#
#                                                          19  \
# House     1 BHK Flat  For Sale  In Gopi-ka-ram Society I...
# Location  Sawarkar Nagar, Sant Dnyaneshwar marg, Borival...
# Area                                        515 sqftBuiltup
# Price                                         ₹48,717/Month
#
#                                                          20  \
# House     1 BHK Flat  For Sale  In Green View Complex In...
# Location  Green View Garden, Nensey Colony, Borivali Eas...
# Area                                        585 sqftBuiltup
# Price                                         ₹57,314/Month
#
#                                                          21  \
# House     2 BHK Flat  For Sale  In Green View Society Bo...
# Location                        Borivali East Nancy colony
# Area                                      1,328 sqftBuiltup
# Price                                      ₹1.09 Lacs/Month
#
#                                                          22  \
# House     1 BHK Flat  For Sale  In Saideep Building In B...
# Location  PN-9 Om Siddhivinayak Society, Kajupada, Boriv...
# Area                                        512 sqftBuiltup
# Price                                         ₹40,693/Month
#
#                                                          23  \
# House     2 BHK Flat  For Sale  In Aditya Aryan In Chogl...
# Location  Chogle Nagar, Borivali East, Mumbai, Maharasht...
# Area                                      1,100 sqftBuiltup
# Price                                         ₹1 Lacs/Month
#
#                                                          24
# House     1 BHK Flat  For Sale  In Shree Mahalaxmi Sra B...
# Location                              near mahakali mandir
# Area                                        325 sqftBuiltup
# Price                                         ₹27,510/Month
#
# [4 rows x 25 columns]
