# %%
#python program to display all the header tags from wikipedia.org

# %%
#installing webscrapping libraries

# %%
# !pip install bs4
# !pip install requests

# %%
#importing important libraries

# %%
from bs4 import BeautifulSoup
import requests

# %%
#sending get request to the webpage server to get source code of the page

# %%
page = requests.get('https://en.wikipedia.org/wiki/Main_Page')

# %%
page
# Out:
# <Response [200]>

# %%
#page content

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
first_title = soup.find('span',class_="mw-headline")
first_title
# Out:
# <span class="mw-headline" id="Welcome_to_Wikipedia">Welcome to <a href="/wiki/Wikipedia" title="Wikipedia">Wikipedia</a></span>

# %%
first_title.text
# Out:
# 'Welcome to Wikipedia'

# %%
titles = []

for i in soup.find_all('span',class_="mw-headline"):
    titles.append(i.text)

    
titles
# Out:
# ['Welcome to Wikipedia',
#  "From today's featured article",
#  'Did you know\xa0...',
#  'In the news',
#  'On this day',
#  "From today's featured list",
#  "Today's featured picture",
#  'Other areas of Wikipedia',
#  "Wikipedia's sister projects",
#  'Wikipedia languages']
